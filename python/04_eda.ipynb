# %%
# ## Business Insight

# - Identified customer distribution across countries.
# - Measured overall churn percentage.
# - Analyzed age, balance, and credit score distributions.
# - Explored customer product ownership and activity status.
# - Generated correlation matrix for numerical features.

# These insights help identify customer behavior patterns and support future business recommendations.

# %%
corr = numeric.corr()

corr
# Out:
#                   customer_id  credit_score       age    tenure   balance  \
# customer_id          1.000000      0.005308  0.009497 -0.014883 -0.012419
# credit_score         0.005308      1.000000 -0.003965  0.000842  0.006268
# age                  0.009497     -0.003965  1.000000 -0.009997  0.028308
# tenure              -0.014883      0.000842 -0.009997  1.000000 -0.012254
# balance             -0.012419      0.006268  0.028308 -0.012254  1.000000
# products             0.016972      0.012238 -0.030680  0.013444 -0.304180
# credit_card         -0.014025     -0.005458 -0.011721  0.022583 -0.014858
# active_member        0.001665      0.025651  0.085472 -0.028362 -0.010084
# estimated_salary     0.015271     -0.001384 -0.007201  0.007784  0.012797
# churn               -0.006248     -0.027094  0.285323 -0.014001  0.118533
#
#                   products  credit_card  active_member  estimated_salary  \
# customer_id       0.016972    -0.014025       0.001665          0.015271
# ...

# %%
numeric = df.select_dtypes(include="number")

numeric.corr()
# Out:
#                   customer_id  credit_score       age    tenure   balance  \
# customer_id          1.000000      0.005308  0.009497 -0.014883 -0.012419
# credit_score         0.005308      1.000000 -0.003965  0.000842  0.006268
# age                  0.009497     -0.003965  1.000000 -0.009997  0.028308
# tenure              -0.014883      0.000842 -0.009997  1.000000 -0.012254
# balance             -0.012419      0.006268  0.028308 -0.012254  1.000000
# products             0.016972      0.012238 -0.030680  0.013444 -0.304180
# credit_card         -0.014025     -0.005458 -0.011721  0.022583 -0.014858
# active_member        0.001665      0.025651  0.085472 -0.028362 -0.010084
# estimated_salary     0.015271     -0.001384 -0.007201  0.007784  0.012797
# churn               -0.006248     -0.027094  0.285323 -0.014001  0.118533
#
#                   products  credit_card  active_member  estimated_salary  \
# customer_id       0.016972    -0.014025       0.001665          0.015271
# ...

# %%
active = df["active_member"].value_counts()

plt.figure(figsize=(5,5))

plt.pie(
    active,
    labels=["Inactive","Active"],
    autopct="%1.1f%%"
)

plt.title("Active vs Inactive Members")

plt.show()

# %%
product_counts = df["products"].value_counts().sort_index()

plt.figure(figsize=(6,4))
product_counts.plot(kind="bar")

plt.title("Products per Customer")
plt.xlabel("Products")
plt.ylabel("Customers")

plt.show()

# %%
plt.figure(figsize=(7,4))

plt.hist(df["credit_score"], bins=20)

plt.title("Credit Score Distribution")
plt.xlabel("Credit Score")
plt.ylabel("Customers")

plt.show()

# %%
plt.figure(figsize=(7,4))

plt.hist(df["balance"], bins=20)

plt.title("Account Balance Distribution")
plt.xlabel("Balance")
plt.ylabel("Customers")

plt.show()

# %%
plt.figure(figsize=(7,4))

plt.hist(df["age"], bins=20)

plt.title("Customer Age Distribution")
plt.xlabel("Age")
plt.ylabel("Customers")

plt.show()

# %%
churn_counts = df["churn"].value_counts()

plt.figure(figsize=(5,5))
plt.pie(
    churn_counts,
    labels=["Retained","Exited"],
    autopct="%1.1f%%"
)

plt.title("Customer Churn Distribution")
plt.show()

# %%
country_counts = df["country"].value_counts()

plt.figure(figsize=(6,4))
country_counts.plot(kind="bar")

plt.title("Customers by Country")
plt.xlabel("Country")
plt.ylabel("Customers")

plt.show()

# %%
username = "postgres"
password = "password"
host = "localhost"
port = "5432"
database = "banking_customer_intelligence"

engine = create_engine(
    f"postgresql://{username}:{password}@{host}:{port}/{database}"
)

df = pd.read_sql("SELECT * FROM customers", engine)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
# # Exploratory Data Analysis (EDA)

# ## Objective

# Explore customer behavior, churn patterns, balance distribution, salary distribution, and relationships between variables to generate business insights.
